# %% [markdown]
# <a href="https://colab.research.google.com/github/Venkatesh1499/MLBase/blob/practice_LinearRegression/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import math

# Data
diabetics = load_diabetes()

x = diabetics.data
y = diabetics.target

# test train split
x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42
)

# Creating the model
model = LinearRegression()

print(y.min())
print(y.max())

# Training the model
model.fit(x_train, y_train)

y_prediction = model.predict(x_test)

mse = mean_squared_error(y_test, y_prediction)
r2 = r2_score(y_test, y_prediction)
print(mse)
print(r2)

diff = y.max() - y.min()
print("diff is", diff)
rmse = math.sqrt(mse)
print("rmse is", rmse)

rmse_percentage = (rmse/diff) * 100
print(rmse_percentage)
# Out:
# 25.0
# 346.0
# 2900.193628493482
# 0.4526027629719195
# diff is 321.0
# rmse is 53.85344583676593
# 167.76774403976924
